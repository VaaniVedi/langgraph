# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict, Annotated
from langchain_core.messages import BaseMessage, HumanMessage
from langchain_openai import ChatOpenAI
from langgraph.graph.message import add_messages
from langgraph.checkpoint.memory import MemorySaver

# %%
class ChatState(TypedDict):
    messages: Annotated[list[BaseMessage], add_messages]
    
    
llm = ChatOpenAI()

# %%
def chat_node(state: ChatState):
    #take user query from state
    messages = state['messages']
    #send to llm
    response = llm.invoke(messages)
    
    #response store state
    return {'messages': [response]}

# %%
checkpointer = MemorySaver()
graph = StateGraph(ChatState)

graph.add_node('chat_node',chat_node)
graph.add_edge(START, 'chat_node')
graph.add_edge('chat_node',END)

chatbot = graph.compile(checkpointer=checkpointer)

chatbot

# %%
initial_state = {
    'messages':[HumanMessage(content = 'What is the capital of India')]
}
thread_id = '1'
config = {'configurable': {'thread_id': thread_id}}
chatbot.invoke(initial_state,config=config)
# Out:
# {'messages': [HumanMessage(content='What is the capital of India', additional_kwargs={}, response_metadata={}, id='f703af79-c3eb-49e9-9f90-21dc20ec7535'),
#   AIMessage(content='The capital of India is New Delhi.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 13, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBSaw7UUOFEOHHYBgxP1lEUCSIl8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01471-18fa-7673-a496-6f8fc8b4c258-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 8, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
thread_id = '1'

while True:
    user_message = input('Type here: ')
    
    print('User: ',user_message)
    
    if user_message.strip().lower() in ['exit','quit','bye']:
        break
    
    config = {'configurable': {'thread_id': thread_id}}
    response = chatbot.invoke({
        'messages': [HumanMessage(content = user_message)]
    },config=config)
    
    print('AI: ', response['messages'][-1].content)
    
chatbot.get_state(config=config)
# Out:
# User:  hi
# AI:  Hello! How can I assist you today?
# User:  vfe
# AI:  I'm sorry, I didn't quite understand that. Can you please provide more information or let me know how I can assist you?
# User:  what is this
# AI:  I am a language model AI assistant designed to help answer questions and engage in conversation. How can I assist you today?
# User:  where is india
# AI:  India is a country located in South Asia, bordered by Pakistan to the northwest, China and Nepal to the north, Bhutan to the northeast, and Bangladesh and Myanmar to the east. It is bounded by the Indian Ocean to the south.
# User:  where is south asia
# AI:  South Asia is a region in Asia that includes countries like India, Pakistan, Bangladesh, Sri Lanka, Nepal, Bhutan, and the Maldives. It is located south of the Himalayas and includes the Indian subcontinent.
# User:  where is that
# AI:  The Indian subcontinent is a region in South Asia that includes the countries of India, Nepal, Bhutan, and part of Bangladesh. It is located in the southern part of the Asian continent, south of the Himalayas.
# User:  -where is that
# AI:  The Indian subcontinent, which is part of South Asia, is located in the southern region of the Asian continent. It is surrounded by the Indian Ocean to the south, the Arabian Sea to the west, and the Bay of Bengal to the east.
# User:  where is that
# AI:  The Indian subcontinent is located in the southern part of the Asian continent. It comprises the countries of India, Nepal, Bhutan, and parts of Bangladesh.
# User:  where is that
# AI:  I apologize for the confusion. The Indian subcontinent is located in South Asia, bordered by the Himalayas to the north and surrounded by the Indian Ocean on the south. It includes countries like India, Nepal, Bhutan, and parts of Bangladesh.
# User:  Where is South Asia
# AI:  South Asia is a region in the southern part of Asia. It includes countries like India, Pakistan, Bangladesh, Nepal, Bhutan, Sri Lanka, and the Maldives.
# User:  Where is Asia
# AI:  Asia is a continent located primarily in the Eastern and Northern Hemispheres of the Earth. It is the largest continent by land area and population, and it is bordered by Europe to the west, the Pacific Ocean to the east, the Arctic Ocean to the north, and the Indian Ocean to the south.
# User:  Where is Earstern and Northern Hemisphere
# AI:  The Earth is divided into halves called hemispheres based on the Equator and Prime Meridian. The Equator divides the Earth into the Northern Hemisphere and Southern Hemisphere, while the Prime Meridian divides it into the Eastern Hemisphere and Western Hemisphere. The Eastern Hemisphere includes countries in Asia, Africa, Europe, and Australia, while the Northern Hemisphere includes countries in North America, Europe, Asia, and part of Africa.
# User:  where is earth
# AI:  The Earth is the third planet from the Sun in our solar system. It is located in the Milky Way galaxy and is the only known planet that sustains life. It is located in the solar system, about 93 million miles away from the Sun.
# User:  exir
# AI:  I'm sorry, I am not sure what you mean by "exir". Can you please provide more context or clarify your question? I'm here to help with any information you need.
# User:  exit
# StateSnapshot(values={'messages': [HumanMessage(content='What is the capital of India', additional_kwargs={}, response_metadata={}, id='f703af79-c3eb-49e9-9f90-21dc20ec7535'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 13, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBSaw7UUOFEOHHYBgxP1lEUCSIl8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01471-18fa-7673-a496-6f8fc8b4c258-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 8, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='7438873d-4f8f-45ce-9f29-756fb0b9ce15'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 30, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBTvnVS8NNaAupeLPrgqQNErjn7S', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01472-5b89-7b22-bf7a-aeec2b1f15c0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 9, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='my name is vani', additional_kwargs={}, response_metadata={}, id='b5854955-b663-4148-84e6-3c824eda83b4'), AIMessage(content='Nice to meet you, Vani! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 52, 'total_tokens': 67, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBTzWpZUrdgpD6fhGLATcekN3avd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01472-70f3-70d0-9b2e-8f70b236e9b7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 15, 'total_tokens': 67, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='ell me my name', additional_kwargs={}, response_metadata={}, id='ab0cd110-d71a-44e7-b2b9-79c583d0d0b8'), AIMessage(content='Your name is Vani.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 79, 'total_tokens': 85, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBU5ak4N5Nml5BpIjvhY6AxIDcxm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01472-8911-72f0-bfcf-c343f638767a-0', tool_calls=[], in ...

# %%
chatbot.get_state(config=config)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='What is the capital of India', additional_kwargs={}, response_metadata={}, id='f703af79-c3eb-49e9-9f90-21dc20ec7535'), AIMessage(content='The capital of India is New Delhi.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 8, 'prompt_tokens': 13, 'total_tokens': 21, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBSaw7UUOFEOHHYBgxP1lEUCSIl8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01471-18fa-7673-a496-6f8fc8b4c258-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 8, 'total_tokens': 21, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='hi', additional_kwargs={}, response_metadata={}, id='7438873d-4f8f-45ce-9f29-756fb0b9ce15'), AIMessage(content='Hello! How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 30, 'total_tokens': 39, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBTvnVS8NNaAupeLPrgqQNErjn7S', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01472-5b89-7b22-bf7a-aeec2b1f15c0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 9, 'total_tokens': 39, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='my name is vani', additional_kwargs={}, response_metadata={}, id='b5854955-b663-4148-84e6-3c824eda83b4'), AIMessage(content='Nice to meet you, Vani! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 52, 'total_tokens': 67, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBTzWpZUrdgpD6fhGLATcekN3avd', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01472-70f3-70d0-9b2e-8f70b236e9b7-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 52, 'output_tokens': 15, 'total_tokens': 67, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), HumanMessage(content='ell me my name', additional_kwargs={}, response_metadata={}, id='ab0cd110-d71a-44e7-b2b9-79c583d0d0b8'), AIMessage(content='Your name is Vani.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 79, 'total_tokens': 85, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-EEBU5ak4N5Nml5BpIjvhY6AxIDcxm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--01a01472-8911-72f0-bfcf-c343f638767a-0', tool_calls=[], in ...
